# %%
import random
from datetime import datetime
from enum import Enum

class ItemType(Enum):
    Sword1H = 1
    Sword2H = 2
    Axe = 3
    Polearm = 4
    ShortBlade = 5
    


class Item:    
    def __init__(self):
        self.names = []
        
    def getRandomFromList(self,L):
        i = random.randint(0,len(L)-1)
        return L[i]
    
    def setName(self):        
        self.name = self.getRandomFromList(self.names)
    
    def setMaterial(self):        
        self.material = self.getRandomFromList(self.mats)
        
    def setDecoration(self):        
        self.decoration = self.getRandomFromList(self.decorations)
        
    def setQuality(self):        
        self.quality = self.getRandomFromList(self.qualities)
    
class ItemController:    
    def setItemSet(Item):
        N = 10
        for i in range(N):
            self.items = Item()
    
    def getItemDetails(self):
        details = self.item.decoration+ " " + self.item.quality + " " + self.item.material + " " + self.item.name
        return details
    def setup(self):
        self.item.setName()
        self.item.setMaterial()
        self.item.setDecoration()
        self.item.setQuality()
        
    def pickWeapons(self):
        items = [ItemType.SWORD1H, ItemType.SWORD2H, ItemType.AXE, ItemType.POLEARM, ItemType.SHORTBLADE]        
        newItemType = random.randint(0,len(items-1))
        
        if newItemType == 1:
            self.item = Sword1h()
        if newItemType == 2:
            self.item = Sword2h()
        if newItemType == 3:
            self.item = Axe()
        if newItemType == 4:
            self.item = Polearm()
        if newItemType == 5:
            self.item = ShortBlade()
                            
            
            
    
class Weapon(Item):
    def __init__(self):        
        super().__init__()
        self.mats = ["Iron", "Mithril", "Adamantite", "Starstone", "Abyssal", "Arkhite", "Steel", "Blacksteel", "Dragonsteel","Damascus Steel"]
        self.decorations = ["Runed", "Inscribed", "Gilded", "Jewelled", "Glittering", "Glowing", "Fiery", "Sparking", "Cold", "Blooded"]
        self.qualities = ["Shoddy", "Worn", "Weathered", "Used", "Regular", "Common", "Fine", "Exquisite", "Masterwork", "Divine", "Fell"]
        
    def attack(index):
        self.attacks[index].use()
        
class TargetStrategy:
    def getTarget(self):
        return self.targetAction + self.targetRange
    
class Swing(TargetStrategy):
    def __init__(self):
        super().__init__()
        self.targetAction = "swings at enemies "
        self.targetRange = "in arms reach"
class Thrust(TargetStrategy):
    def __init__(self):
        super().__init__()
        self.targetAction = "thrusts at enemies "
        self.targetRange = "a short step away"
        
class Slam(TargetStrategy):
    def __init__(self):
        super().__init__()
        self.targetAction = "slams down upon enemies"
        self.targetRange = "in front of you"

class Projectile(TargetStrategy):
    def __init__(self):
        super().__init__()
        self.targetAction = "sails towards enemies "
        self.targetRange = "in the distance"

class AoE(TargetStrategy):
    def __init__(self):
        super().__init__()
        self.targetAction = "blasts enemies"
        self.targetRange = "in a large area around you"
        
class Melee(Weapon):
    def __init__(self):
        super().__init__()
        
class Sword(Melee):
    def __init__(self):
        super().__init__()

class Sword2H(Sword):
    def __init__(self):
        super().__init__()
        self.names = ["Greatsword", "Bastard Sword", "Zweihander", "Katana"]

class Sword1H(Sword):
    def __init__(self):
        super().__init__()
        self.names = ["Longsword", "Cutlass", "Falchion", "Rapier"]

class Axe(Melee):
    def __init__(self):
        super().__init__()
        self.names = ["Axe", "Hatchet"]        

class Polearm(Melee):
    def __init__(self):
        super().__init__()
        self.names = ["Spear", "Halberd", "Pike", "Lance"]
    
class ShortBlade(Melee):
    def __init__(self):
        super().__init__()
        self.names = ["Dagger", "Knife", "Hook", "Scythe", "Shortsword"]
    
class Armour(Item):
    def __init__(self):
        super().__init__()
        self.names = ["Skirt", "Greaves", "Gloves", "Torso", "Boots", "Pauldron", "Helmet", "Shield"]
        self.mats = ["Leather", "Cloth", "Iron", "Mithril", "Adamantite", "Abyssal", "Arkhite", "Steel", "Blacksteel", "Dragonsteel"]
        self.decorations = ["Runed", "Inscribed", "Gilded", "Jewelled", "Dirty", "Dented"]
        self.qualities = ["Shoddy", "Worn", "Weathered", "Used", "Regular", "Common", "Fine", "Exquisite", "Masterwork"]
    
N = 10
itemList = []
weaponList = []

for i in range(N):
    itemList.append(ItemController())
    itemList[i].pickWeapons()
    itemList[i].setup

print("Weapons:")
for i in range(N):    
    print(itemList[i].getItemDetails())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-51420f0f01cd> in <module>
#     155 for i in range(N):
#     156     itemList.append(ItemController())
# --> 157     itemList[i].pickWeapons()
#     158     itemList[i].setup
#     159
#
# <ipython-input-1-51420f0f01cd> in pickWeapons(self)
#      48
#      49     def pickWeapons(self):
# ---> 50         items = [ItemType.SWORD1H, ItemType.SWORD2H, ItemType.AXE, ItemType.POLEARM, ItemType.SHORTBLADE]
#      51         newItemType = random.randint(0,len(items-1))
#      52
#
# D:\Dev\Anaconda\lib\enum.py in __getattr__(cls, name)
#     347             return cls._member_map_[name]
#     348         except KeyError:
# --> 349             raise AttributeError(name) from None
#     350
#     351     def __getitem__(cls, name):
#
# AttributeError: SWORD1H
